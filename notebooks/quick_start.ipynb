# %% [markdown]
# # CT Scan Analysis - Quick Start
#
# This notebook demonstrates how to use the CT scan analysis project for medical imaging classification.
#
# **MEDICAL DISCLAIMER**: This is a research demonstration project for educational purposes only. It is NOT intended for clinical use, medical diagnosis, or treatment decisions.
